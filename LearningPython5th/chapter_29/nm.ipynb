# %%
import numpy
import pandas as pandas

a = 4
b = 5
c = a+b
print(c)
# Out:
# 9

# %%
import pandas as pd

df = pd.read_excel(r'C:\Users\Mher Matevosyan\Desktop\del.xlsx')
print(df)
# Out:
#     Ինտերնետ բանկից ներմուծված գործառնություններ         Unnamed: 1  \
# 0                                        Ամսաթիվ  Հաշվարկային հաշիվ
# 1                            2022-08-30 00:00:00   1660018847240100
# 2                            2022-08-30 00:00:00   1660018847240100
# 3                            2022-08-30 00:00:00   1660018847240100
# 4                            2022-08-30 00:00:00   1660018847240100
# ..                                           ...                ...
# 270                          2022-08-30 00:00:00   1660018847240100
# 271                          2022-08-30 00:00:00   1660018847240100
# 272                          2022-08-30 00:00:00   1660018847240100
# 273                          2022-08-30 00:00:00   1660018847240100
# 274                                          NaN                NaN
#
#      Unnamed: 2   Unnamed: 3      Unnamed: 4  \
# 0         Դեբետ  Փաստաթղթի N  Թղթակցող հաշիվ
# 1         45470       203798    163738005079
# ...

# %%
data = pd.read_excel(r'C:\Users\Mher Matevosyan\Desktop\del.xlsx')
df = pd.DataFrame(data, columns=['Ամսաթիվ'])
print(df)
# Out:
#      Ամսաթիվ
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# ..       ...
# 270      NaN
# 271      NaN
# 272      NaN
# 273      NaN
# 274      NaN
#
# [275 rows x 1 columns]
